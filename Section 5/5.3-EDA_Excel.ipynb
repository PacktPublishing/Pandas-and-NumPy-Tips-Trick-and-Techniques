# %% [markdown]
# # Exploratory Data Analysis

# %%
import pandas as pd
# %matplotlib inline

# %%
data = pd.read_excel('AMZN.xlsx')
data.head()
# Out:
#         Date        High         Low        Open       Close   Volume  \
# 0 2017-01-03  758.760010  747.700012  757.919983  753.669983  3521100
# 1 2017-01-04  759.679993  754.200012  758.390015  757.179993  2510500
# 2 2017-01-05  782.400024  760.260010  761.549988  780.450012  5830100
# 3 2017-01-06  799.440002  778.479980  782.359985  795.989990  5986200
# 4 2017-01-09  801.770020  791.770020  798.000000  796.919983  3446100
#
#     Adj Close
# 0  753.669983
# 1  757.179993
# 2  780.450012
# 3  795.989990
# 4  796.919983

# %%
data.describe()
# Out:
#               High          Low         Open        Close        Volume  \
# count   674.000000   674.000000   674.000000   674.000000  6.740000e+02
# mean   1444.045075  1414.812419  1430.886349  1430.193472  4.503249e+06
# std     395.859384   385.978603   391.677133   390.857529  2.247504e+06
# min     758.760010   747.700012   757.919983   753.669983  1.585100e+06
# 25%     999.455002   986.017487   996.209991   993.529999  2.964000e+06
# 50%    1575.385010  1523.614990  1552.434998  1548.239990  3.824200e+06
# 75%    1799.357513  1758.922485  1784.097504  1778.774963  5.373175e+06
# max    2050.500000  2013.000000  2038.109985  2039.510010  1.656500e+07
#
#          Adj Close
# count   674.000000
# mean   1430.193472
# std     390.857529
# min     753.669983
# 25%     993.529999
# 50%    1548.239990
# 75%    1778.774963
# max    2039.510010

# %%
data['Volume'].plot(kind='hist', bins=50)

# %%
data.plot(kind='scatter', x='Open', y='Close')

# %%
# Install pandas_profiling at the command line:
# pip install pandas_profiling
import pandas_profiling

# %%
prof = data.profile_report()

# %%
prof.to_file(output_file="test_pro.html")

# %%
# This does not work in MS Edge currently
prof
# Out:
#                 <iframe
#                     width="100%"
#                     height="800px"
#                     srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;utf-8&quot;&gt;
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;
#     &lt;meta name=&quot;description&quot; content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;
#     &lt;meta name=&quot;author&quot; content=&quot;Jos Polfliet, Simon Brugman and the open source community.&quot;&gt;
#     &lt;meta name=&quot;generator&quot; content=&quot;Pandas Profiling 2.3.0&quot; /&gt;
#     &lt;meta name=&quot;url&quot; content=&quot;https://github.com/pandas-profiling/pandas-profiling&quot;&gt;
#
#     &lt;title&gt;Pandas Profiling Report&lt;/title&gt;
#
# &lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
# ...

# %%
# Out:
#                 <iframe
#                     width="100%"
#                     height="800px"
#                     srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;utf-8&quot;&gt;
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;
#     &lt;meta name=&quot;description&quot; content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;
#     &lt;meta name=&quot;author&quot; content=&quot;Jos Polfliet, Simon Brugman and the open source community.&quot;&gt;
#     &lt;meta name=&quot;generator&quot; content=&quot;Pandas Profiling 2.3.0&quot; /&gt;
#     &lt;meta name=&quot;url&quot; content=&quot;https://github.com/pandas-profiling/pandas-profiling&quot;&gt;
#
#     &lt;title&gt;Pandas Profiling Report&lt;/title&gt;
#
# &lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
# ...
